# %%
import pandas as pd

df = pd.read_csv('./files/Salaries.csv')

df.head()
# Out:
# C:\Users\wecan\AppData\Local\Temp\ipykernel_15584\2066698830.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./files/Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %%
# Ustun nomlarini chiqarish
print("Ustun nomlari:", df.columns.tolist())

# Har bir ustunning ma'lumot turini ko'rish
print("\nUstunlardagi ma'lumot turlari:\n", df.dtypes)
# Out:
# Ustun nomlari: ['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency', 'Status']
# *********
#
# Ustunlardagi ma'lumot turlari:
#  Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
katta_yoshlar = df.query("TotalPay > 200000")
katta_yoshlar.shape
# Out:
# (2008, 13)

# %%
San_fransisko = df[df['Status'].isin(['FT'])]

San_fransisko.shape
# Out:
# (22334, 13)

# %%
pivot = df.pivot_table(values='TotalPay', index='EmployeeName', aggfunc='mean')
pivot
# Out:
#                         TotalPay
# EmployeeName
# A BERNARD FATOOH       20039.910
# A Bernard  Fatooh      23923.620
# A Bernard Fatooh       21280.770
# A ELIZABETH MARCHASIN  26282.860
# A JAMIL NIAZI          87496.210
# ...                          ...
# Zun Jin Zhang He       57820.370
# Zuna Luu               52518.080
# Zuna T Luu             56121.675
# Zuri  Jones            71986.900
# Zuri Jones             76628.030
#
# [110811 rows x 1 columns]
