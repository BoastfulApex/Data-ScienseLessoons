# %%
import pandas as pd

# Datasetni yuklash
url = "https://raw.githubusercontent.com/Apress/data-analysis-and-visualization-using-python/master/Ch07/Salaries.csv"
df = pd.read_csv(url)

# Datasetning hajmini ko'rish
rows, columns = df.shape
print(f"Datasetda {rows} ta qator va {columns} ta ustun bor.")
# Out:
# Datasetda 78 ta qator va 6 ta ustun bor.

# %%
# Ustun nomlarini chiqarish
print("Ustun nomlari:", df.columns.tolist())

# Har bir ustunning ma'lumot turini ko'rish
print("\nUstunlardagi ma'lumot turlari:\n", df.dtypes)
# Out:
# Ustun nomlari: ['rank', 'discipline', 'phd', 'service', 'sex', 'salary']
#
# Ustunlardagi ma'lumot turlari:
#  rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
# Birinchi 5 ta qatorni chiqarish
print(df.head())
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# Har bir ustunda nechta null qiymat borligini tekshirish
print(df.isnull().sum())
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# Null qiymatlarni tashlab yuborish
df.dropna(inplace=True)
